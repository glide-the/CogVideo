# %%
import torch

# %%
from typing import Any, Dict


def get_state_dict(saved_dict: Dict[str, Any]) -> Dict[str, Any]:
    state_dict = saved_dict
    if "model" in saved_dict.keys():
        state_dict = state_dict["model"]
    if "module" in saved_dict.keys():
        state_dict = state_dict["module"]
    if "state_dict" in saved_dict.keys():
        state_dict = state_dict["state_dict"]
    return state_dict

# %%
from diffusers.models.modeling_utils import ModelMixin, load_state_dict
model_file = '/mnt/ceph/develop/jiawei/model_checkpoint/hf_cogvideoxlora/pytorch_lora_weights.safetensors'
state_dict1 = load_state_dict(model_file)

# %%
list(state_dict1.keys())
# Out:
# ['text_encoder.encoder.block.0.layer.0.SelfAttention.k.lora_A.weight',
#  'text_encoder.encoder.block.0.layer.0.SelfAttention.k.lora_B.weight',
#  'text_encoder.encoder.block.0.layer.0.SelfAttention.o.lora_A.weight',
#  'text_encoder.encoder.block.0.layer.0.SelfAttention.o.lora_B.weight',
#  'text_encoder.encoder.block.0.layer.0.SelfAttention.q.lora_A.weight',
#  'text_encoder.encoder.block.0.layer.0.SelfAttention.q.lora_B.weight',
#  'text_encoder.encoder.block.0.layer.0.SelfAttention.v.lora_A.weight',
#  'text_encoder.encoder.block.0.layer.0.SelfAttention.v.lora_B.weight',
#  'text_encoder.encoder.block.1.layer.0.SelfAttention.k.lora_A.weight',
#  'text_encoder.encoder.block.1.layer.0.SelfAttention.k.lora_B.weight',
#  'text_encoder.encoder.block.1.layer.0.SelfAttention.o.lora_A.weight',
#  'text_encoder.encoder.block.1.layer.0.SelfAttention.o.lora_B.weight',
#  'text_encoder.encoder.block.1.layer.0.SelfAttention.q.lora_A.weight',
#  'text_encoder.encoder.block.1.layer.0.SelfAttention.q.lora_B.weight',
#  'text_encoder.encoder.block.1.layer.0.SelfAttention.v.lora_A.weight',
#  'text_encoder.encoder.block.1.layer.0.SelfAttention.v.lora_B.weight',
#  'text_encoder.encoder.block.10.layer.0.SelfAttention.k.lora_A.weight',
#  'text_encoder.encoder.block.10.layer.0.SelfAttention.k.lora_B.weight',
#  'text_encoder.encoder.block.10.layer.0.SelfAttention.o.lora_A.weight',
#  'text_encoder.encoder.block.10.layer.0.SelfAttention.o.lora_B.weight',
#  'text_encoder.encoder.block.10.layer.0.SelfAttention.q.lora_A.weight',
#  'text_encoder.encoder.block.10.layer.0.SelfAttention.q.lora_B.weight',
#  'text_encoder.encoder.block.10.layer.0.SelfAttention.v.lora_A.weight',
#  'text_encoder.encoder.block.10.layer.0.SelfAttention.v.lora_B.weight',
#  'text_encoder.encoder.block.11.layer.0.SelfAttention.k.lora_A.weight',
#  'text_encoder.encoder.block.11.layer.0.SelfAttention.k.lora_B.weight',
#  'text_encoder.encoder.block.11.layer.0.SelfAttention.o.lora_A.weight',
#  'text_encoder.encoder.block.11.layer.0.SelfAttention.o.lora_B.weight',
#  'text_encoder.encoder.block.11.layer.0.SelfAttention.q.lora_A.weight',
#  'text_encoder.encoder.block.11.layer.0.SelfAttention.q.lora_B.weight',
#  'text_encoder.encoder.block.11.layer.0.SelfAttention.v.lora_A.weight',
#  'text_encoder.encoder.block.11.layer.0.SelfAttention.v.lora_B.weight',
#  'text_encoder.encoder.block.12.layer.0.SelfAttention.k.lora_A.weight',
#  'text_encoder.encoder.block.12.layer.0.SelfAttention.k.lora_B.weight',
#  'text_encoder.encoder.block.12.layer.0.SelfAttention.o.lora_A.weight',
#  'text_encoder.encoder.block.12.layer.0.SelfAttention.o.lora_B.weight',
#  'text_encoder.encoder.block.12.layer.0.SelfAttention.q.lora_A.weight',
#  'text_encoder.encoder.block.12.layer.0.SelfAttention.q.lora_B.weight',
#  'text_encoder.encoder.block.12.layer.0.SelfAttention.v.lora_A.weight',
#  'text_encoder.encoder.block.12.layer.0.SelfAttention.v.lora_B.weight',
#  'text_encoder.encoder.block.13.layer.0.SelfAttention.k.lora_A.weight',
#  'text_encoder.encoder.block.13.layer.0.SelfAttention.k.lora_B.weight',
#  'text_encoder.encoder.block.13.layer.0.SelfAttention.o.lora_A.weight',
#  'text_encoder.encoder.block.13.layer.0.SelfAttention.o.lora_B.weight',
#  'text_encoder.encoder.block.13.layer.0.SelfAttention.q.lora_A.weight',
#  'text_encoder.encoder.block.13.layer.0.SelfAttention.q.lora_B.weight',
#  'text_encoder.encoder.block.13.layer.0.SelfAttention.v.lora_A.weight',
#  'text_encoder.encoder.block.13.layer.0.SelfAttention.v.lora_B.weight',
#  'text_encoder.encoder.block.14.layer.0.SelfAttention.k.lora_A.weight',
#  'text_encoder.encoder.block.14.layer.0.SelfAttention.k.lora_B.weight',
#  'text_encoder.encoder.block.14.layer.0.SelfAttention.o.lora_A.weight',
#  'text_encoder.encoder.block.14.layer.0.SelfAttention.o.lora_B.weight',
#  'text_encoder.encoder.block.14.layer.0.SelfAttention.q.lora_A.weight',
#  'text_encoder.encoder.block.14.layer.0.SelfAttention.q.lora_B.weight',
#  'text_encoder.encoder.block.14.layer.0.SelfAttention.v.lora_A.weight',
#  'text_encoder.encoder.block.14.layer.0.SelfAttention.v.lora_B.weight',
#  'text_encoder.encoder.block.15.layer.0.SelfAttention.k.lora_A.weight',
#  'text_encoder.encoder.block.15.layer.0.SelfAttention.k.lora_B.weight',
#  'text_encoder.encoder.block.15.layer.0.SelfAttention.o.lora_A.weight',
#  'text_encoder.encoder.block.15.layer.0.SelfAttention.o.lora_B.weight',
#  'text_encoder.encoder.block.15.layer.0.SelfAttention.q.lora_A.weight',
#  'text_encoder.encoder.block.15.layer.0.SelfAttention.q.lora_B.weight',
#  'text_encoder.encoder.block.15.layer.0.SelfAttention.v.lora_A.weight',
#  'text_encoder.encoder.block.15.layer.0.SelfAttention.v.lora_B.weight',
#  'text_encoder.encoder.block.16.layer.0.SelfAttention.k.lora_A.weight',
#  'text_encoder.encoder.block.16.layer.0.SelfAttention.k.lora_B.weight',
#  'text_encoder.encoder.block.16.layer.0.SelfAttention.o.lora_A.weight',
#  'text_encoder.encoder.block.16.layer.0.SelfAttention.o.lora_B.weight',
#  'text_encoder.encoder.block.16.layer.0.SelfAttention.q.lora_A.weight',
#  'text_encoder.encoder.block.16.layer.0.SelfAttention.q.lora_B.weight',
#  'text_encoder.encoder.block.16.layer.0.SelfAttention.v.lora_A.weight',
#  'text_encoder.encoder.block.16.layer.0.SelfAttention.v.lora_B.weight',
#  'text_encoder.encoder.block.17.layer.0.SelfAttention.k.lora_A.weight',
#  'text_encoder.encoder.block.17.layer.0.SelfAttention.k.lora_B.weight',
#  'text_encoder.encoder.block.17.layer.0.SelfAttention.o.lora_A.weight',
#  'text_encoder.encoder.block.17.layer.0.SelfAttention.o.lora_B.weight',
#  'text_encoder.encoder.block.17.layer.0.SelfAttention.q.lora_A.weight',
#  'text_encoder.encoder.block.17.layer.0.SelfAttention.q.lora_B.weight',
#  'text_encoder.encoder.block.17.layer.0.SelfAttention.v.lora_A.weight',
#  'text_encoder.encoder.block.17.layer.0.SelfAttention.v.lora_B.weight',
#  'text_encoder.encoder.block.18.layer.0.SelfAttention.k.lora_A.weight',
#  'text_encoder.encoder.block.18.layer.0.SelfAttention.k.lora_B.weight',
#  'text_encoder.encoder.block.18.layer.0.SelfAttention.o.lora_A.weight',
#  'text_encoder.encoder.block.18.layer.0.SelfAttention.o.lora_B.weight',
#  'text_encoder.encoder.block.18.layer.0.SelfAttention.q.lora_A.weight',
#  'text_encoder.encoder.block.18.layer.0.SelfAttention.q.lora_B.weight',
#  'text_encoder.encoder.block.18.layer.0.SelfAttention.v.lora_A.weight',
#  'text_encoder.encoder.block.18.layer.0.SelfAttention.v.lora_B.weight',
#  'text_encoder.encoder.block.19.layer.0.SelfAttention.k.lora_A.weight',
#  'text_encoder.encoder.block.19.layer.0.SelfAttention.k.lora_B.weight',
#  'text_encoder.encoder.block.19.layer.0.SelfAttention.o.lora_A.weight',
#  'text_encoder.encoder.block.19.layer.0.SelfAttention.o.lora_B.weight',
#  'text_encoder.encoder.block.19.layer.0.SelfAttention.q.lora_A.weight',
#  'text_encoder.encoder.block.19.layer.0.SelfAttention.q.lora_B.weight',
#  'text_encoder.encoder.block.19.layer.0.SelfAttention.v.lora_A.weight',
#  'text_encoder.encoder.block.19.layer.0.SelfAttention.v.lora_B.weight',
#  'text_encoder.encoder.block.2.layer.0.SelfAttention.k.lora_A.weight',
#  'text_encoder.encoder.block.2.layer.0.SelfAttention.k.lora_B.weight',
#  'text_encoder.encoder.block.2.layer.0.SelfAttention.o.lora_A.weight',
#  'text_encoder.encoder.block.2.layer.0.SelfAttention.o.lora_B.weight',
#  'text_encoder.encoder.block.2.layer.0.SelfAttention.q.lora_A.weight',
#  'text_encoder.encoder.block.2.layer.0.SelfAttention.q.lora_B.weight',
#  'text_encoder.encoder.block.2.layer.0.SelfAttention.v.lora_A.weight',
#  'text_encoder.encoder.block.2.layer.0.SelfAttention.v.lora_B.weight',
#  'text_encoder.encoder.block.20.layer.0.SelfAttention.k.lora_A.weight',
#  'text_encoder.encoder.block.20.layer.0.SelfAttention.k.lora_B.weight',
#  'text_encoder.encoder.block.20.layer.0.SelfAttention.o.lora_A.weight',
#  'text_encoder.encoder.block.20.layer.0.SelfAttention.o.lora_B.weight',
#  'text_encoder.encoder.block.20.layer.0.SelfAttention.q.lora_A.weight',
#  'text_encoder.encoder.block.20.layer.0.SelfAttention.q.lora_B.weight',
#  'text_encoder.encoder.block.20.layer.0.SelfAttention.v.lora_A.weight',
#  'text_encoder.encoder.block.20.layer.0.SelfAttention.v.lora_B.weight',
#  'text_encoder.encoder.block.21.layer.0.SelfAttention.k.lora_A.weight',
#  'text_encoder.encoder.block.21.layer.0.SelfAttention.k.lora_B.weight',
#  'text_encoder.encoder.block.21.layer.0.SelfAttention.o.lora_A.weight',
#  'text_encoder.encoder.block.21.layer.0.SelfAttention.o.lora_B.weight',
#  'text_encoder.encoder.block.21.layer.0.SelfAttention.q.lora_A.weight',
#  'text_encoder.encoder.block.21.layer.0.SelfAttention.q.lora_B.weight',
#  'text_encoder.encoder.block.21.layer.0.SelfAttention.v.lora_A.weight',
#  'text_encoder.encoder.block.21.layer.0.SelfAttention.v.lora_B.weight',
#  'text_encoder.encoder.block.22.layer.0.SelfAttention.k.lora_A.weight',
#  'text_encoder.encoder.block.22.layer.0.SelfAttention.k.lora_B.weight',
#  'text_encoder.encoder.block.22.layer.0.SelfAttention.o.lora_A.weight',
#  'text_encoder.encoder.block.22.layer.0.SelfAttention.o.lora_B.weight',
#  'text_encoder.encoder.block.22.layer.0.SelfAttention.q.lora_A.weight',
#  'text_encoder.encoder.block.22.layer.0.SelfAttention.q.lora_B.weight',
#  'text_encoder.encoder.block.22.layer.0.SelfAttention.v.lora_A.weight',
#  'text_encoder.encoder.block.22.layer.0.SelfAttention.v.lora_B.weight',
#  'text_encoder.encoder.block.23.layer.0.SelfAttention.k.lora_A.weight',
#  'text_encoder.encoder.block.23.layer.0.SelfAttention.k.lora_B.weight',
#  'text_encoder.encoder.block.23.layer.0.SelfAttention.o.lora_A.weight',
#  'text_encoder.encoder.block.23.layer.0.SelfAttention.o.lora_B.weight',
#  'text_encoder.encoder.block.23.layer.0.SelfAttention.q.lora_A.weight',
#  'text_encoder.encoder.block.23.layer.0.SelfAttention.q.lora_B.weight',
#  'text_encoder.encoder.block.23.layer.0.SelfAttention.v.lora_A.weight',
#  'text_encoder.encoder.block.23.layer.0.SelfAttention.v.lora_B.weight',
#  'text_encoder.encoder.block.3.layer.0.SelfAttention.k.lora_A.weight',
#  'text_encoder.encoder.block.3.layer.0.SelfAttention.k.lora_B.weight',
#  'text_encoder.encoder.block.3.layer.0.SelfAttention.o.lora_A.weight',
#  'text_encoder.encoder.block.3.layer.0.SelfAttention.o.lora_B.weight',
#  'text_encoder.encoder.block.3.layer.0.SelfAttention.q.lora_A.weight',
#  'text_encoder.encoder.block.3.layer.0.SelfAttention.q.lora_B.weight',
#  'text_encoder.encoder.block.3.layer.0.SelfAttention.v.lora_A.weight',
#  'text_encoder.encoder.block.3.layer.0.SelfAttention.v.lora_B.weight',
#  'text_encoder.encoder.block.4.layer.0.SelfAttention.k.lora_A.weight',
#  'text_encoder.encoder.block.4.layer.0.SelfAttention.k.lora_B.weight',
#  'text_encoder.encoder.block.4.layer.0.SelfAttention.o.lora_A.weight',
#  'text_encoder.encoder.block.4.layer.0.SelfAttention.o.lora_B.weight',
#  'text_encoder.encoder.block.4.layer.0.SelfAttention.q.lora_A.weight',
#  'text_encoder.encoder.block.4.layer.0.SelfAttention.q.lora_B.weight',
#  'text_encoder.encoder.block.4.layer.0.SelfAttention.v.lora_A.weight',
#  'text_encoder.encoder.block.4.layer.0.SelfAttention.v.lora_B.weight',
#  'text_encoder.encoder.block.5.layer.0.SelfAttention.k.lora_A.weight',
#  'text_encoder.encoder.block.5.layer.0.SelfAttention.k.lora_B.weight',
#  'text_encoder.encoder.block.5.layer.0.SelfAttention.o.lora_A.weight',
#  'text_encoder.encoder.block.5.layer.0.SelfAttention.o.lora_B.weight',
#  'text_encoder.encoder.block.5.layer.0.SelfAttention.q.lora_A.weight',
#  'text_encoder.encoder.block.5.layer.0.SelfAttention.q.lora_B.weight',
#  'text_encoder.encoder.block.5.layer.0.SelfAttention.v.lora_A.weight',
#  'text_encoder.encoder.block.5.layer.0.SelfAttention.v.lora_B.weight',
#  'text_encoder.encoder.block.6.layer.0.SelfAttention.k.lora_A.weight',
#  'text_encoder.encoder.block.6.layer.0.SelfAttention.k.lora_B.weight',
#  'text_encoder.encoder.block.6.layer.0.SelfAttention.o.lora_A.weight',
#  'text_encoder.encoder.block.6.layer.0.SelfAttention.o.lora_B.weight',
#  'text_encoder.encoder.block.6.layer.0.SelfAttention.q.lora_A.weight',
#  'text_encoder.encoder.block.6.layer.0.SelfAttention.q.lora_B.weight',
#  'text_encoder.encoder.block.6.layer.0.SelfAttention.v.lora_A.weight',
#  'text_encoder.encoder.block.6.layer.0.SelfAttention.v.lora_B.weight',
#  'text_encoder.encoder.block.7.layer.0.SelfAttention.k.lora_A.weight',
#  'text_encoder.encoder.block.7.layer.0.SelfAttention.k.lora_B.weight',
#  'text_encoder.encoder.block.7.layer.0.SelfAttention.o.lora_A.weight',
#  'text_encoder.encoder.block.7.layer.0.SelfAttention.o.lora_B.weight',
#  'text_encoder.encoder.block.7.layer.0.SelfAttention.q.lora_A.weight',
#  'text_encoder.encoder.block.7.layer.0.SelfAttention.q.lora_B.weight',
#  'text_encoder.encoder.block.7.layer.0.SelfAttention.v.lora_A.weight',
#  'text_encoder.encoder.block.7.layer.0.SelfAttention.v.lora_B.weight',
#  'text_encoder.encoder.block.8.layer.0.SelfAttention.k.lora_A.weight',
#  'text_encoder.encoder.block.8.layer.0.SelfAttention.k.lora_B.weight',
#  'text_encoder.encoder.block.8.layer.0.SelfAttention.o.lora_A.weight',
#  'text_encoder.encoder.block.8.layer.0.SelfAttention.o.lora_B.weight',
#  'text_encoder.encoder.block.8.layer.0.SelfAttention.q.lora_A.weight',
#  'text_encoder.encoder.block.8.layer.0.SelfAttention.q.lora_B.weight',
#  'text_encoder.encoder.block.8.layer.0.SelfAttention.v.lora_A.weight',
#  'text_encoder.encoder.block.8.layer.0.SelfAttention.v.lora_B.weight',
#  'text_encoder.encoder.block.9.layer.0.SelfAttention.k.lora_A.weight',
#  'text_encoder.encoder.block.9.layer.0.SelfAttention.k.lora_B.weight',
#  'text_encoder.encoder.block.9.layer.0.SelfAttention.o.lora_A.weight',
#  'text_encoder.encoder.block.9.layer.0.SelfAttention.o.lora_B.weight',
#  'text_encoder.encoder.block.9.layer.0.SelfAttention.q.lora_A.weight',
#  'text_encoder.encoder.block.9.layer.0.SelfAttention.q.lora_B.weight',
#  'text_encoder.encoder.block.9.layer.0.SelfAttention.v.lora_A.weight',
#  'text_encoder.encoder.block.9.layer.0.SelfAttention.v.lora_B.weight',
#  'transformer.transformer_blocks.0.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.0.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.0.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.0.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.0.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.0.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.0.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.0.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.1.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.1.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.1.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.1.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.1.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.1.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.1.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.1.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.10.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.10.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.10.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.10.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.10.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.10.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.10.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.10.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.11.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.11.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.11.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.11.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.11.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.11.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.11.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.11.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.12.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.12.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.12.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.12.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.12.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.12.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.12.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.12.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.13.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.13.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.13.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.13.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.13.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.13.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.13.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.13.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.14.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.14.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.14.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.14.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.14.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.14.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.14.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.14.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.15.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.15.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.15.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.15.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.15.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.15.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.15.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.15.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.16.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.16.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.16.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.16.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.16.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.16.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.16.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.16.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.17.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.17.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.17.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.17.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.17.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.17.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.17.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.17.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.18.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.18.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.18.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.18.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.18.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.18.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.18.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.18.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.19.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.19.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.19.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.19.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.19.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.19.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.19.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.19.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.2.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.2.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.2.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.2.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.2.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.2.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.2.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.2.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.20.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.20.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.20.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.20.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.20.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.20.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.20.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.20.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.21.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.21.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.21.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.21.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.21.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.21.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.21.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.21.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.22.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.22.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.22.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.22.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.22.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.22.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.22.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.22.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.23.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.23.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.23.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.23.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.23.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.23.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.23.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.23.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.24.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.24.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.24.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.24.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.24.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.24.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.24.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.24.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.25.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.25.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.25.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.25.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.25.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.25.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.25.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.25.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.26.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.26.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.26.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.26.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.26.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.26.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.26.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.26.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.27.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.27.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.27.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.27.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.27.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.27.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.27.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.27.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.28.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.28.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.28.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.28.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.28.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.28.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.28.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.28.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.29.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.29.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.29.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.29.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.29.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.29.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.29.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.29.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.3.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.3.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.3.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.3.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.3.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.3.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.3.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.3.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.4.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.4.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.4.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.4.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.4.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.4.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.4.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.4.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.5.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.5.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.5.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.5.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.5.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.5.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.5.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.5.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.6.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.6.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.6.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.6.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.6.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.6.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.6.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.6.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.7.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.7.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.7.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.7.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.7.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.7.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.7.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.7.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.8.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.8.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.8.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.8.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.8.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.8.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.8.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.8.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.9.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.9.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.9.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.9.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.9.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.9.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.9.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.9.attn1.to_v.lora_B.weight']

# %%
list(state_dict1.keys())
# Out:
# ['transformer.transformer_blocks.0.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.0.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.0.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.0.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.0.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.0.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.0.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.0.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.1.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.1.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.1.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.1.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.1.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.1.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.1.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.1.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.10.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.10.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.10.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.10.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.10.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.10.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.10.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.10.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.11.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.11.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.11.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.11.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.11.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.11.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.11.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.11.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.12.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.12.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.12.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.12.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.12.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.12.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.12.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.12.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.13.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.13.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.13.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.13.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.13.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.13.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.13.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.13.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.14.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.14.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.14.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.14.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.14.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.14.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.14.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.14.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.15.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.15.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.15.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.15.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.15.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.15.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.15.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.15.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.16.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.16.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.16.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.16.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.16.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.16.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.16.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.16.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.17.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.17.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.17.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.17.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.17.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.17.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.17.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.17.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.18.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.18.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.18.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.18.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.18.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.18.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.18.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.18.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.19.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.19.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.19.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.19.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.19.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.19.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.19.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.19.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.2.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.2.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.2.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.2.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.2.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.2.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.2.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.2.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.20.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.20.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.20.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.20.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.20.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.20.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.20.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.20.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.21.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.21.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.21.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.21.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.21.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.21.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.21.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.21.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.22.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.22.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.22.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.22.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.22.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.22.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.22.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.22.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.23.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.23.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.23.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.23.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.23.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.23.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.23.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.23.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.24.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.24.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.24.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.24.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.24.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.24.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.24.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.24.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.25.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.25.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.25.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.25.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.25.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.25.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.25.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.25.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.26.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.26.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.26.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.26.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.26.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.26.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.26.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.26.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.27.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.27.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.27.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.27.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.27.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.27.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.27.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.27.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.28.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.28.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.28.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.28.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.28.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.28.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.28.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.28.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.29.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.29.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.29.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.29.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.29.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.29.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.29.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.29.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.3.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.3.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.3.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.3.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.3.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.3.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.3.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.3.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.4.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.4.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.4.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.4.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.4.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.4.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.4.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.4.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.5.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.5.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.5.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.5.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.5.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.5.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.5.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.5.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.6.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.6.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.6.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.6.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.6.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.6.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.6.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.6.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.7.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.7.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.7.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.7.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.7.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.7.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.7.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.7.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.8.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.8.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.8.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.8.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.8.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.8.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.8.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.8.attn1.to_v.lora_B.weight',
#  'transformer.transformer_blocks.9.attn1.to_k.lora_A.weight',
#  'transformer.transformer_blocks.9.attn1.to_k.lora_B.weight',
#  'transformer.transformer_blocks.9.attn1.to_out.0.lora_A.weight',
#  'transformer.transformer_blocks.9.attn1.to_out.0.lora_B.weight',
#  'transformer.transformer_blocks.9.attn1.to_q.lora_A.weight',
#  'transformer.transformer_blocks.9.attn1.to_q.lora_B.weight',
#  'transformer.transformer_blocks.9.attn1.to_v.lora_A.weight',
#  'transformer.transformer_blocks.9.attn1.to_v.lora_B.weight']

# %%
model_file = '/mnt/ceph/develop/jiawei/model_checkpoint/export_hf_lora_weights/pytorch_lora_weights.safetensors'
state_dict2 = load_state_dict(model_file)

len(list(state_dict2.keys()))
# Out:
# 240

# %%
state_dict1.keys()-state_dict2.keys()
# Out:
# set()

# %%
from diffusers.models.modeling_utils import ModelMixin, load_state_dict
model_file = '/mnt/ceph/develop/jiawei/model_checkpoint/ckpts_2b_lora/lora-disney-09-09-21-10/1000/mp_rank_00_model_states.pt'
merge_original_state_dict = get_state_dict(torch.load(model_file, map_location="cpu", mmap=True))
# Out:
# /tmp/ipykernel_3373831/1950247920.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   merge_original_state_dict = get_state_dict(torch.load(model_file, map_location="cpu", mmap=True))

# %%
list(merge_original_state_dict.keys())
# Out:
# ['model.diffusion_model.mixins.pos_embed.pos_embedding',
#  'model.diffusion_model.mixins.patch_embed.proj.weight',
#  'model.diffusion_model.mixins.patch_embed.proj.bias',
#  'model.diffusion_model.mixins.patch_embed.text_proj.weight',
#  'model.diffusion_model.mixins.patch_embed.text_proj.bias',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.0.1.weight',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.0.1.bias',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.1.1.weight',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.1.1.bias',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.2.1.weight',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.2.1.bias',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.3.1.weight',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.3.1.bias',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.4.1.weight',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.4.1.bias',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.5.1.weight',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.5.1.bias',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.6.1.weight',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.6.1.bias',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.7.1.weight',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.7.1.bias',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.8.1.weight',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.8.1.bias',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.9.1.weight',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.9.1.bias',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.10.1.weight',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.10.1.bias',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.11.1.weight',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.11.1.bias',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.12.1.weight',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.12.1.bias',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.13.1.weight',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.13.1.bias',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.14.1.weight',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.14.1.bias',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.15.1.weight',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.15.1.bias',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.16.1.weight',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.16.1.bias',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.17.1.weight',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.17.1.bias',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.18.1.weight',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.18.1.bias',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.19.1.weight',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.19.1.bias',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.20.1.weight',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.20.1.bias',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.21.1.weight',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.21.1.bias',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.22.1.weight',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.22.1.bias',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.23.1.weight',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.23.1.bias',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.24.1.weight',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.24.1.bias',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.25.1.weight',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.25.1.bias',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.26.1.weight',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.26.1.bias',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.27.1.weight',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.27.1.bias',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.28.1.weight',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.28.1.bias',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.29.1.weight',
#  'model.diffusion_model.mixins.adaln_layer.adaLN_modulations.29.1.bias',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.0.weight',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.0.bias',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.1.weight',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.1.bias',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.2.weight',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.2.bias',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.3.weight',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.3.bias',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.4.weight',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.4.bias',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.5.weight',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.5.bias',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.6.weight',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.6.bias',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.7.weight',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.7.bias',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.8.weight',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.8.bias',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.9.weight',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.9.bias',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.10.weight',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.10.bias',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.11.weight',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.11.bias',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.12.weight',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.12.bias',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.13.weight',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.13.bias',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.14.weight',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.14.bias',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.15.weight',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.15.bias',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.16.weight',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.16.bias',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.17.weight',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.17.bias',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.18.weight',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.18.bias',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.19.weight',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.19.bias',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.20.weight',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.20.bias',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.21.weight',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.21.bias',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.22.weight',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.22.bias',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.23.weight',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.23.bias',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.24.weight',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.24.bias',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.25.weight',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.25.bias',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.26.weight',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.26.bias',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.27.weight',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.27.bias',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.28.weight',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.28.bias',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.29.weight',
#  'model.diffusion_model.mixins.adaln_layer.query_layernorm_list.29.bias',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.0.weight',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.0.bias',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.1.weight',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.1.bias',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.2.weight',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.2.bias',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.3.weight',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.3.bias',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.4.weight',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.4.bias',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.5.weight',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.5.bias',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.6.weight',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.6.bias',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.7.weight',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.7.bias',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.8.weight',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.8.bias',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.9.weight',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.9.bias',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.10.weight',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.10.bias',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.11.weight',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.11.bias',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.12.weight',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.12.bias',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.13.weight',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.13.bias',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.14.weight',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.14.bias',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.15.weight',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.15.bias',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.16.weight',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.16.bias',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.17.weight',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.17.bias',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.18.weight',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.18.bias',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.19.weight',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.19.bias',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.20.weight',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.20.bias',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.21.weight',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.21.bias',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.22.weight',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.22.bias',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.23.weight',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.23.bias',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.24.weight',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.24.bias',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.25.weight',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.25.bias',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.26.weight',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.26.bias',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.27.weight',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.27.bias',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.28.weight',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.28.bias',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.29.weight',
#  'model.diffusion_model.mixins.adaln_layer.key_layernorm_list.29.bias',
#  'model.diffusion_model.mixins.final_layer.norm_final.weight',
#  'model.diffusion_model.mixins.final_layer.norm_final.bias',
#  'model.diffusion_model.mixins.final_layer.linear.weight',
#  'model.diffusion_model.mixins.final_layer.linear.bias',
#  'model.diffusion_model.mixins.final_layer.adaLN_modulation.1.weight',
#  'model.diffusion_model.mixins.final_layer.adaLN_modulation.1.bias',
#  'model.diffusion_model.transformer.layers.0.input_layernorm.weight',
#  'model.diffusion_model.transformer.layers.0.input_layernorm.bias',
#  'model.diffusion_model.transformer.layers.0.attention.query_key_value.original.weight',
#  'model.diffusion_model.transformer.layers.0.attention.query_key_value.original.bias',
#  'model.diffusion_model.transformer.layers.0.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.0.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.0.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.0.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.0.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.0.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.0.attention.dense.original.weight',
#  'model.diffusion_model.transformer.layers.0.attention.dense.original.bias',
#  'model.diffusion_model.transformer.layers.0.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.0.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.0.post_attention_layernorm.weight',
#  'model.diffusion_model.transformer.layers.0.post_attention_layernorm.bias',
#  'model.diffusion_model.transformer.layers.0.mlp.dense_h_to_4h.weight',
#  'model.diffusion_model.transformer.layers.0.mlp.dense_h_to_4h.bias',
#  'model.diffusion_model.transformer.layers.0.mlp.dense_4h_to_h.weight',
#  'model.diffusion_model.transformer.layers.0.mlp.dense_4h_to_h.bias',
#  'model.diffusion_model.transformer.layers.1.input_layernorm.weight',
#  'model.diffusion_model.transformer.layers.1.input_layernorm.bias',
#  'model.diffusion_model.transformer.layers.1.attention.query_key_value.original.weight',
#  'model.diffusion_model.transformer.layers.1.attention.query_key_value.original.bias',
#  'model.diffusion_model.transformer.layers.1.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.1.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.1.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.1.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.1.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.1.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.1.attention.dense.original.weight',
#  'model.diffusion_model.transformer.layers.1.attention.dense.original.bias',
#  'model.diffusion_model.transformer.layers.1.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.1.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.1.post_attention_layernorm.weight',
#  'model.diffusion_model.transformer.layers.1.post_attention_layernorm.bias',
#  'model.diffusion_model.transformer.layers.1.mlp.dense_h_to_4h.weight',
#  'model.diffusion_model.transformer.layers.1.mlp.dense_h_to_4h.bias',
#  'model.diffusion_model.transformer.layers.1.mlp.dense_4h_to_h.weight',
#  'model.diffusion_model.transformer.layers.1.mlp.dense_4h_to_h.bias',
#  'model.diffusion_model.transformer.layers.2.input_layernorm.weight',
#  'model.diffusion_model.transformer.layers.2.input_layernorm.bias',
#  'model.diffusion_model.transformer.layers.2.attention.query_key_value.original.weight',
#  'model.diffusion_model.transformer.layers.2.attention.query_key_value.original.bias',
#  'model.diffusion_model.transformer.layers.2.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.2.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.2.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.2.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.2.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.2.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.2.attention.dense.original.weight',
#  'model.diffusion_model.transformer.layers.2.attention.dense.original.bias',
#  'model.diffusion_model.transformer.layers.2.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.2.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.2.post_attention_layernorm.weight',
#  'model.diffusion_model.transformer.layers.2.post_attention_layernorm.bias',
#  'model.diffusion_model.transformer.layers.2.mlp.dense_h_to_4h.weight',
#  'model.diffusion_model.transformer.layers.2.mlp.dense_h_to_4h.bias',
#  'model.diffusion_model.transformer.layers.2.mlp.dense_4h_to_h.weight',
#  'model.diffusion_model.transformer.layers.2.mlp.dense_4h_to_h.bias',
#  'model.diffusion_model.transformer.layers.3.input_layernorm.weight',
#  'model.diffusion_model.transformer.layers.3.input_layernorm.bias',
#  'model.diffusion_model.transformer.layers.3.attention.query_key_value.original.weight',
#  'model.diffusion_model.transformer.layers.3.attention.query_key_value.original.bias',
#  'model.diffusion_model.transformer.layers.3.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.3.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.3.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.3.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.3.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.3.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.3.attention.dense.original.weight',
#  'model.diffusion_model.transformer.layers.3.attention.dense.original.bias',
#  'model.diffusion_model.transformer.layers.3.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.3.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.3.post_attention_layernorm.weight',
#  'model.diffusion_model.transformer.layers.3.post_attention_layernorm.bias',
#  'model.diffusion_model.transformer.layers.3.mlp.dense_h_to_4h.weight',
#  'model.diffusion_model.transformer.layers.3.mlp.dense_h_to_4h.bias',
#  'model.diffusion_model.transformer.layers.3.mlp.dense_4h_to_h.weight',
#  'model.diffusion_model.transformer.layers.3.mlp.dense_4h_to_h.bias',
#  'model.diffusion_model.transformer.layers.4.input_layernorm.weight',
#  'model.diffusion_model.transformer.layers.4.input_layernorm.bias',
#  'model.diffusion_model.transformer.layers.4.attention.query_key_value.original.weight',
#  'model.diffusion_model.transformer.layers.4.attention.query_key_value.original.bias',
#  'model.diffusion_model.transformer.layers.4.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.4.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.4.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.4.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.4.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.4.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.4.attention.dense.original.weight',
#  'model.diffusion_model.transformer.layers.4.attention.dense.original.bias',
#  'model.diffusion_model.transformer.layers.4.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.4.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.4.post_attention_layernorm.weight',
#  'model.diffusion_model.transformer.layers.4.post_attention_layernorm.bias',
#  'model.diffusion_model.transformer.layers.4.mlp.dense_h_to_4h.weight',
#  'model.diffusion_model.transformer.layers.4.mlp.dense_h_to_4h.bias',
#  'model.diffusion_model.transformer.layers.4.mlp.dense_4h_to_h.weight',
#  'model.diffusion_model.transformer.layers.4.mlp.dense_4h_to_h.bias',
#  'model.diffusion_model.transformer.layers.5.input_layernorm.weight',
#  'model.diffusion_model.transformer.layers.5.input_layernorm.bias',
#  'model.diffusion_model.transformer.layers.5.attention.query_key_value.original.weight',
#  'model.diffusion_model.transformer.layers.5.attention.query_key_value.original.bias',
#  'model.diffusion_model.transformer.layers.5.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.5.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.5.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.5.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.5.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.5.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.5.attention.dense.original.weight',
#  'model.diffusion_model.transformer.layers.5.attention.dense.original.bias',
#  'model.diffusion_model.transformer.layers.5.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.5.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.5.post_attention_layernorm.weight',
#  'model.diffusion_model.transformer.layers.5.post_attention_layernorm.bias',
#  'model.diffusion_model.transformer.layers.5.mlp.dense_h_to_4h.weight',
#  'model.diffusion_model.transformer.layers.5.mlp.dense_h_to_4h.bias',
#  'model.diffusion_model.transformer.layers.5.mlp.dense_4h_to_h.weight',
#  'model.diffusion_model.transformer.layers.5.mlp.dense_4h_to_h.bias',
#  'model.diffusion_model.transformer.layers.6.input_layernorm.weight',
#  'model.diffusion_model.transformer.layers.6.input_layernorm.bias',
#  'model.diffusion_model.transformer.layers.6.attention.query_key_value.original.weight',
#  'model.diffusion_model.transformer.layers.6.attention.query_key_value.original.bias',
#  'model.diffusion_model.transformer.layers.6.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.6.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.6.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.6.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.6.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.6.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.6.attention.dense.original.weight',
#  'model.diffusion_model.transformer.layers.6.attention.dense.original.bias',
#  'model.diffusion_model.transformer.layers.6.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.6.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.6.post_attention_layernorm.weight',
#  'model.diffusion_model.transformer.layers.6.post_attention_layernorm.bias',
#  'model.diffusion_model.transformer.layers.6.mlp.dense_h_to_4h.weight',
#  'model.diffusion_model.transformer.layers.6.mlp.dense_h_to_4h.bias',
#  'model.diffusion_model.transformer.layers.6.mlp.dense_4h_to_h.weight',
#  'model.diffusion_model.transformer.layers.6.mlp.dense_4h_to_h.bias',
#  'model.diffusion_model.transformer.layers.7.input_layernorm.weight',
#  'model.diffusion_model.transformer.layers.7.input_layernorm.bias',
#  'model.diffusion_model.transformer.layers.7.attention.query_key_value.original.weight',
#  'model.diffusion_model.transformer.layers.7.attention.query_key_value.original.bias',
#  'model.diffusion_model.transformer.layers.7.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.7.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.7.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.7.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.7.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.7.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.7.attention.dense.original.weight',
#  'model.diffusion_model.transformer.layers.7.attention.dense.original.bias',
#  'model.diffusion_model.transformer.layers.7.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.7.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.7.post_attention_layernorm.weight',
#  'model.diffusion_model.transformer.layers.7.post_attention_layernorm.bias',
#  'model.diffusion_model.transformer.layers.7.mlp.dense_h_to_4h.weight',
#  'model.diffusion_model.transformer.layers.7.mlp.dense_h_to_4h.bias',
#  'model.diffusion_model.transformer.layers.7.mlp.dense_4h_to_h.weight',
#  'model.diffusion_model.transformer.layers.7.mlp.dense_4h_to_h.bias',
#  'model.diffusion_model.transformer.layers.8.input_layernorm.weight',
#  'model.diffusion_model.transformer.layers.8.input_layernorm.bias',
#  'model.diffusion_model.transformer.layers.8.attention.query_key_value.original.weight',
#  'model.diffusion_model.transformer.layers.8.attention.query_key_value.original.bias',
#  'model.diffusion_model.transformer.layers.8.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.8.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.8.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.8.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.8.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.8.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.8.attention.dense.original.weight',
#  'model.diffusion_model.transformer.layers.8.attention.dense.original.bias',
#  'model.diffusion_model.transformer.layers.8.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.8.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.8.post_attention_layernorm.weight',
#  'model.diffusion_model.transformer.layers.8.post_attention_layernorm.bias',
#  'model.diffusion_model.transformer.layers.8.mlp.dense_h_to_4h.weight',
#  'model.diffusion_model.transformer.layers.8.mlp.dense_h_to_4h.bias',
#  'model.diffusion_model.transformer.layers.8.mlp.dense_4h_to_h.weight',
#  'model.diffusion_model.transformer.layers.8.mlp.dense_4h_to_h.bias',
#  'model.diffusion_model.transformer.layers.9.input_layernorm.weight',
#  'model.diffusion_model.transformer.layers.9.input_layernorm.bias',
#  'model.diffusion_model.transformer.layers.9.attention.query_key_value.original.weight',
#  'model.diffusion_model.transformer.layers.9.attention.query_key_value.original.bias',
#  'model.diffusion_model.transformer.layers.9.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.9.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.9.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.9.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.9.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.9.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.9.attention.dense.original.weight',
#  'model.diffusion_model.transformer.layers.9.attention.dense.original.bias',
#  'model.diffusion_model.transformer.layers.9.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.9.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.9.post_attention_layernorm.weight',
#  'model.diffusion_model.transformer.layers.9.post_attention_layernorm.bias',
#  'model.diffusion_model.transformer.layers.9.mlp.dense_h_to_4h.weight',
#  'model.diffusion_model.transformer.layers.9.mlp.dense_h_to_4h.bias',
#  'model.diffusion_model.transformer.layers.9.mlp.dense_4h_to_h.weight',
#  'model.diffusion_model.transformer.layers.9.mlp.dense_4h_to_h.bias',
#  'model.diffusion_model.transformer.layers.10.input_layernorm.weight',
#  'model.diffusion_model.transformer.layers.10.input_layernorm.bias',
#  'model.diffusion_model.transformer.layers.10.attention.query_key_value.original.weight',
#  'model.diffusion_model.transformer.layers.10.attention.query_key_value.original.bias',
#  'model.diffusion_model.transformer.layers.10.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.10.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.10.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.10.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.10.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.10.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.10.attention.dense.original.weight',
#  'model.diffusion_model.transformer.layers.10.attention.dense.original.bias',
#  'model.diffusion_model.transformer.layers.10.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.10.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.10.post_attention_layernorm.weight',
#  'model.diffusion_model.transformer.layers.10.post_attention_layernorm.bias',
#  'model.diffusion_model.transformer.layers.10.mlp.dense_h_to_4h.weight',
#  'model.diffusion_model.transformer.layers.10.mlp.dense_h_to_4h.bias',
#  'model.diffusion_model.transformer.layers.10.mlp.dense_4h_to_h.weight',
#  'model.diffusion_model.transformer.layers.10.mlp.dense_4h_to_h.bias',
#  'model.diffusion_model.transformer.layers.11.input_layernorm.weight',
#  'model.diffusion_model.transformer.layers.11.input_layernorm.bias',
#  'model.diffusion_model.transformer.layers.11.attention.query_key_value.original.weight',
#  'model.diffusion_model.transformer.layers.11.attention.query_key_value.original.bias',
#  'model.diffusion_model.transformer.layers.11.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.11.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.11.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.11.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.11.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.11.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.11.attention.dense.original.weight',
#  'model.diffusion_model.transformer.layers.11.attention.dense.original.bias',
#  'model.diffusion_model.transformer.layers.11.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.11.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.11.post_attention_layernorm.weight',
#  'model.diffusion_model.transformer.layers.11.post_attention_layernorm.bias',
#  'model.diffusion_model.transformer.layers.11.mlp.dense_h_to_4h.weight',
#  'model.diffusion_model.transformer.layers.11.mlp.dense_h_to_4h.bias',
#  'model.diffusion_model.transformer.layers.11.mlp.dense_4h_to_h.weight',
#  'model.diffusion_model.transformer.layers.11.mlp.dense_4h_to_h.bias',
#  'model.diffusion_model.transformer.layers.12.input_layernorm.weight',
#  'model.diffusion_model.transformer.layers.12.input_layernorm.bias',
#  'model.diffusion_model.transformer.layers.12.attention.query_key_value.original.weight',
#  'model.diffusion_model.transformer.layers.12.attention.query_key_value.original.bias',
#  'model.diffusion_model.transformer.layers.12.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.12.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.12.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.12.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.12.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.12.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.12.attention.dense.original.weight',
#  'model.diffusion_model.transformer.layers.12.attention.dense.original.bias',
#  'model.diffusion_model.transformer.layers.12.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.12.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.12.post_attention_layernorm.weight',
#  'model.diffusion_model.transformer.layers.12.post_attention_layernorm.bias',
#  'model.diffusion_model.transformer.layers.12.mlp.dense_h_to_4h.weight',
#  'model.diffusion_model.transformer.layers.12.mlp.dense_h_to_4h.bias',
#  'model.diffusion_model.transformer.layers.12.mlp.dense_4h_to_h.weight',
#  'model.diffusion_model.transformer.layers.12.mlp.dense_4h_to_h.bias',
#  'model.diffusion_model.transformer.layers.13.input_layernorm.weight',
#  'model.diffusion_model.transformer.layers.13.input_layernorm.bias',
#  'model.diffusion_model.transformer.layers.13.attention.query_key_value.original.weight',
#  'model.diffusion_model.transformer.layers.13.attention.query_key_value.original.bias',
#  'model.diffusion_model.transformer.layers.13.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.13.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.13.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.13.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.13.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.13.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.13.attention.dense.original.weight',
#  'model.diffusion_model.transformer.layers.13.attention.dense.original.bias',
#  'model.diffusion_model.transformer.layers.13.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.13.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.13.post_attention_layernorm.weight',
#  'model.diffusion_model.transformer.layers.13.post_attention_layernorm.bias',
#  'model.diffusion_model.transformer.layers.13.mlp.dense_h_to_4h.weight',
#  'model.diffusion_model.transformer.layers.13.mlp.dense_h_to_4h.bias',
#  'model.diffusion_model.transformer.layers.13.mlp.dense_4h_to_h.weight',
#  'model.diffusion_model.transformer.layers.13.mlp.dense_4h_to_h.bias',
#  'model.diffusion_model.transformer.layers.14.input_layernorm.weight',
#  'model.diffusion_model.transformer.layers.14.input_layernorm.bias',
#  'model.diffusion_model.transformer.layers.14.attention.query_key_value.original.weight',
#  'model.diffusion_model.transformer.layers.14.attention.query_key_value.original.bias',
#  'model.diffusion_model.transformer.layers.14.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.14.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.14.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.14.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.14.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.14.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.14.attention.dense.original.weight',
#  'model.diffusion_model.transformer.layers.14.attention.dense.original.bias',
#  'model.diffusion_model.transformer.layers.14.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.14.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.14.post_attention_layernorm.weight',
#  'model.diffusion_model.transformer.layers.14.post_attention_layernorm.bias',
#  'model.diffusion_model.transformer.layers.14.mlp.dense_h_to_4h.weight',
#  'model.diffusion_model.transformer.layers.14.mlp.dense_h_to_4h.bias',
#  'model.diffusion_model.transformer.layers.14.mlp.dense_4h_to_h.weight',
#  'model.diffusion_model.transformer.layers.14.mlp.dense_4h_to_h.bias',
#  'model.diffusion_model.transformer.layers.15.input_layernorm.weight',
#  'model.diffusion_model.transformer.layers.15.input_layernorm.bias',
#  'model.diffusion_model.transformer.layers.15.attention.query_key_value.original.weight',
#  'model.diffusion_model.transformer.layers.15.attention.query_key_value.original.bias',
#  'model.diffusion_model.transformer.layers.15.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.15.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.15.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.15.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.15.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.15.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.15.attention.dense.original.weight',
#  'model.diffusion_model.transformer.layers.15.attention.dense.original.bias',
#  'model.diffusion_model.transformer.layers.15.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.15.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.15.post_attention_layernorm.weight',
#  'model.diffusion_model.transformer.layers.15.post_attention_layernorm.bias',
#  'model.diffusion_model.transformer.layers.15.mlp.dense_h_to_4h.weight',
#  'model.diffusion_model.transformer.layers.15.mlp.dense_h_to_4h.bias',
#  'model.diffusion_model.transformer.layers.15.mlp.dense_4h_to_h.weight',
#  'model.diffusion_model.transformer.layers.15.mlp.dense_4h_to_h.bias',
#  'model.diffusion_model.transformer.layers.16.input_layernorm.weight',
#  'model.diffusion_model.transformer.layers.16.input_layernorm.bias',
#  'model.diffusion_model.transformer.layers.16.attention.query_key_value.original.weight',
#  'model.diffusion_model.transformer.layers.16.attention.query_key_value.original.bias',
#  'model.diffusion_model.transformer.layers.16.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.16.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.16.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.16.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.16.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.16.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.16.attention.dense.original.weight',
#  'model.diffusion_model.transformer.layers.16.attention.dense.original.bias',
#  'model.diffusion_model.transformer.layers.16.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.16.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.16.post_attention_layernorm.weight',
#  'model.diffusion_model.transformer.layers.16.post_attention_layernorm.bias',
#  'model.diffusion_model.transformer.layers.16.mlp.dense_h_to_4h.weight',
#  'model.diffusion_model.transformer.layers.16.mlp.dense_h_to_4h.bias',
#  'model.diffusion_model.transformer.layers.16.mlp.dense_4h_to_h.weight',
#  'model.diffusion_model.transformer.layers.16.mlp.dense_4h_to_h.bias',
#  'model.diffusion_model.transformer.layers.17.input_layernorm.weight',
#  'model.diffusion_model.transformer.layers.17.input_layernorm.bias',
#  'model.diffusion_model.transformer.layers.17.attention.query_key_value.original.weight',
#  'model.diffusion_model.transformer.layers.17.attention.query_key_value.original.bias',
#  'model.diffusion_model.transformer.layers.17.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.17.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.17.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.17.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.17.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.17.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.17.attention.dense.original.weight',
#  'model.diffusion_model.transformer.layers.17.attention.dense.original.bias',
#  'model.diffusion_model.transformer.layers.17.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.17.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.17.post_attention_layernorm.weight',
#  'model.diffusion_model.transformer.layers.17.post_attention_layernorm.bias',
#  'model.diffusion_model.transformer.layers.17.mlp.dense_h_to_4h.weight',
#  'model.diffusion_model.transformer.layers.17.mlp.dense_h_to_4h.bias',
#  'model.diffusion_model.transformer.layers.17.mlp.dense_4h_to_h.weight',
#  'model.diffusion_model.transformer.layers.17.mlp.dense_4h_to_h.bias',
#  'model.diffusion_model.transformer.layers.18.input_layernorm.weight',
#  'model.diffusion_model.transformer.layers.18.input_layernorm.bias',
#  'model.diffusion_model.transformer.layers.18.attention.query_key_value.original.weight',
#  'model.diffusion_model.transformer.layers.18.attention.query_key_value.original.bias',
#  'model.diffusion_model.transformer.layers.18.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.18.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.18.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.18.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.18.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.18.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.18.attention.dense.original.weight',
#  'model.diffusion_model.transformer.layers.18.attention.dense.original.bias',
#  'model.diffusion_model.transformer.layers.18.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.18.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.18.post_attention_layernorm.weight',
#  'model.diffusion_model.transformer.layers.18.post_attention_layernorm.bias',
#  'model.diffusion_model.transformer.layers.18.mlp.dense_h_to_4h.weight',
#  'model.diffusion_model.transformer.layers.18.mlp.dense_h_to_4h.bias',
#  'model.diffusion_model.transformer.layers.18.mlp.dense_4h_to_h.weight',
#  'model.diffusion_model.transformer.layers.18.mlp.dense_4h_to_h.bias',
#  'model.diffusion_model.transformer.layers.19.input_layernorm.weight',
#  'model.diffusion_model.transformer.layers.19.input_layernorm.bias',
#  'model.diffusion_model.transformer.layers.19.attention.query_key_value.original.weight',
#  'model.diffusion_model.transformer.layers.19.attention.query_key_value.original.bias',
#  'model.diffusion_model.transformer.layers.19.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.19.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.19.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.19.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.19.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.19.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.19.attention.dense.original.weight',
#  'model.diffusion_model.transformer.layers.19.attention.dense.original.bias',
#  'model.diffusion_model.transformer.layers.19.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.19.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.19.post_attention_layernorm.weight',
#  'model.diffusion_model.transformer.layers.19.post_attention_layernorm.bias',
#  'model.diffusion_model.transformer.layers.19.mlp.dense_h_to_4h.weight',
#  'model.diffusion_model.transformer.layers.19.mlp.dense_h_to_4h.bias',
#  'model.diffusion_model.transformer.layers.19.mlp.dense_4h_to_h.weight',
#  'model.diffusion_model.transformer.layers.19.mlp.dense_4h_to_h.bias',
#  'model.diffusion_model.transformer.layers.20.input_layernorm.weight',
#  'model.diffusion_model.transformer.layers.20.input_layernorm.bias',
#  'model.diffusion_model.transformer.layers.20.attention.query_key_value.original.weight',
#  'model.diffusion_model.transformer.layers.20.attention.query_key_value.original.bias',
#  'model.diffusion_model.transformer.layers.20.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.20.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.20.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.20.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.20.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.20.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.20.attention.dense.original.weight',
#  'model.diffusion_model.transformer.layers.20.attention.dense.original.bias',
#  'model.diffusion_model.transformer.layers.20.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.20.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.20.post_attention_layernorm.weight',
#  'model.diffusion_model.transformer.layers.20.post_attention_layernorm.bias',
#  'model.diffusion_model.transformer.layers.20.mlp.dense_h_to_4h.weight',
#  'model.diffusion_model.transformer.layers.20.mlp.dense_h_to_4h.bias',
#  'model.diffusion_model.transformer.layers.20.mlp.dense_4h_to_h.weight',
#  'model.diffusion_model.transformer.layers.20.mlp.dense_4h_to_h.bias',
#  'model.diffusion_model.transformer.layers.21.input_layernorm.weight',
#  'model.diffusion_model.transformer.layers.21.input_layernorm.bias',
#  'model.diffusion_model.transformer.layers.21.attention.query_key_value.original.weight',
#  'model.diffusion_model.transformer.layers.21.attention.query_key_value.original.bias',
#  'model.diffusion_model.transformer.layers.21.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.21.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.21.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.21.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.21.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.21.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.21.attention.dense.original.weight',
#  'model.diffusion_model.transformer.layers.21.attention.dense.original.bias',
# ...
#  'conditioner.embedders.0.transformer.encoder.block.2.layer.0.SelfAttention.q.weight',
#  'conditioner.embedders.0.transformer.encoder.block.2.layer.0.SelfAttention.k.weight',
#  'conditioner.embedders.0.transformer.encoder.block.2.layer.0.SelfAttention.v.weight',
#  'conditioner.embedders.0.transformer.encoder.block.2.layer.0.SelfAttention.o.weight',
#  'conditioner.embedders.0.transformer.encoder.block.2.layer.0.layer_norm.weight',
#  'conditioner.embedders.0.transformer.encoder.block.2.layer.1.DenseReluDense.wi_0.weight',
#  'conditioner.embedders.0.transformer.encoder.block.2.layer.1.DenseReluDense.wi_1.weight',
#  'conditioner.embedders.0.transformer.encoder.block.2.layer.1.DenseReluDense.wo.weight',
#  'conditioner.embedders.0.transformer.encoder.block.2.layer.1.layer_norm.weight',
#  'conditioner.embedders.0.transformer.encoder.block.3.layer.0.SelfAttention.q.weight',
#  'conditioner.embedders.0.transformer.encoder.block.3.layer.0.SelfAttention.k.weight',
#  'conditioner.embedders.0.transformer.encoder.block.3.layer.0.SelfAttention.v.weight',
#  'conditioner.embedders.0.transformer.encoder.block.3.layer.0.SelfAttention.o.weight',
#  'conditioner.embedders.0.transformer.encoder.block.3.layer.0.layer_norm.weight',
#  'conditioner.embedders.0.transformer.encoder.block.3.layer.1.DenseReluDense.wi_0.weight',
#  'conditioner.embedders.0.transformer.encoder.block.3.layer.1.DenseReluDense.wi_1.weight',
#  'conditioner.embedders.0.transformer.encoder.block.3.layer.1.DenseReluDense.wo.weight',
#  'conditioner.embedders.0.transformer.encoder.block.3.layer.1.layer_norm.weight',
#  'conditioner.embedders.0.transformer.encoder.block.4.layer.0.SelfAttention.q.weight',
#  'conditioner.embedders.0.transformer.encoder.block.4.layer.0.SelfAttention.k.weight',
#  'conditioner.embedders.0.transformer.encoder.block.4.layer.0.SelfAttention.v.weight',
#  'conditioner.embedders.0.transformer.encoder.block.4.layer.0.SelfAttention.o.weight',
#  'conditioner.embedders.0.transformer.encoder.block.4.layer.0.layer_norm.weight',
#  'conditioner.embedders.0.transformer.encoder.block.4.layer.1.DenseReluDense.wi_0.weight',
#  'conditioner.embedders.0.transformer.encoder.block.4.layer.1.DenseReluDense.wi_1.weight',
#  'conditioner.embedders.0.transformer.encoder.block.4.layer.1.DenseReluDense.wo.weight',
#  'conditioner.embedders.0.transformer.encoder.block.4.layer.1.layer_norm.weight',
#  'conditioner.embedders.0.transformer.encoder.block.5.layer.0.SelfAttention.q.weight',
#  'conditioner.embedders.0.transformer.encoder.block.5.layer.0.SelfAttention.k.weight',
#  'conditioner.embedders.0.transformer.encoder.block.5.layer.0.SelfAttention.v.weight',
#  'conditioner.embedders.0.transformer.encoder.block.5.layer.0.SelfAttention.o.weight',
#  'conditioner.embedders.0.transformer.encoder.block.5.layer.0.layer_norm.weight',
#  'conditioner.embedders.0.transformer.encoder.block.5.layer.1.DenseReluDense.wi_0.weight',
#  'conditioner.embedders.0.transformer.encoder.block.5.layer.1.DenseReluDense.wi_1.weight',
#  'conditioner.embedders.0.transformer.encoder.block.5.layer.1.DenseReluDense.wo.weight',
#  'conditioner.embedders.0.transformer.encoder.block.5.layer.1.layer_norm.weight',
#  'conditioner.embedders.0.transformer.encoder.block.6.layer.0.SelfAttention.q.weight',
#  'conditioner.embedders.0.transformer.encoder.block.6.layer.0.SelfAttention.k.weight',
#  'conditioner.embedders.0.transformer.encoder.block.6.layer.0.SelfAttention.v.weight',
#  'conditioner.embedders.0.transformer.encoder.block.6.layer.0.SelfAttention.o.weight',
#  'conditioner.embedders.0.transformer.encoder.block.6.layer.0.layer_norm.weight',
#  'conditioner.embedders.0.transformer.encoder.block.6.layer.1.DenseReluDense.wi_0.weight',
#  'conditioner.embedders.0.transformer.encoder.block.6.layer.1.DenseReluDense.wi_1.weight',
#  'conditioner.embedders.0.transformer.encoder.block.6.layer.1.DenseReluDense.wo.weight',
#  'conditioner.embedders.0.transformer.encoder.block.6.layer.1.layer_norm.weight',
#  'conditioner.embedders.0.transformer.encoder.block.7.layer.0.SelfAttention.q.weight',
#  'conditioner.embedders.0.transformer.encoder.block.7.layer.0.SelfAttention.k.weight',
#  'conditioner.embedders.0.transformer.encoder.block.7.layer.0.SelfAttention.v.weight',
#  'conditioner.embedders.0.transformer.encoder.block.7.layer.0.SelfAttention.o.weight',
#  'conditioner.embedders.0.transformer.encoder.block.7.layer.0.layer_norm.weight',
#  'conditioner.embedders.0.transformer.encoder.block.7.layer.1.DenseReluDense.wi_0.weight',
#  'conditioner.embedders.0.transformer.encoder.block.7.layer.1.DenseReluDense.wi_1.weight',
#  'conditioner.embedders.0.transformer.encoder.block.7.layer.1.DenseReluDense.wo.weight',
#  'conditioner.embedders.0.transformer.encoder.block.7.layer.1.layer_norm.weight',
#  'conditioner.embedders.0.transformer.encoder.block.8.layer.0.SelfAttention.q.weight',
#  'conditioner.embedders.0.transformer.encoder.block.8.layer.0.SelfAttention.k.weight',
#  'conditioner.embedders.0.transformer.encoder.block.8.layer.0.SelfAttention.v.weight',
#  'conditioner.embedders.0.transformer.encoder.block.8.layer.0.SelfAttention.o.weight',
#  'conditioner.embedders.0.transformer.encoder.block.8.layer.0.layer_norm.weight',
#  'conditioner.embedders.0.transformer.encoder.block.8.layer.1.DenseReluDense.wi_0.weight',
#  'conditioner.embedders.0.transformer.encoder.block.8.layer.1.DenseReluDense.wi_1.weight',
#  'conditioner.embedders.0.transformer.encoder.block.8.layer.1.DenseReluDense.wo.weight',
#  'conditioner.embedders.0.transformer.encoder.block.8.layer.1.layer_norm.weight',
#  'conditioner.embedders.0.transformer.encoder.block.9.layer.0.SelfAttention.q.weight',
#  'conditioner.embedders.0.transformer.encoder.block.9.layer.0.SelfAttention.k.weight',
#  'conditioner.embedders.0.transformer.encoder.block.9.layer.0.SelfAttention.v.weight',
#  'conditioner.embedders.0.transformer.encoder.block.9.layer.0.SelfAttention.o.weight',
#  'conditioner.embedders.0.transformer.encoder.block.9.layer.0.layer_norm.weight',
#  'conditioner.embedders.0.transformer.encoder.block.9.layer.1.DenseReluDense.wi_0.weight',
#  'conditioner.embedders.0.transformer.encoder.block.9.layer.1.DenseReluDense.wi_1.weight',
#  'conditioner.embedders.0.transformer.encoder.block.9.layer.1.DenseReluDense.wo.weight',
#  'conditioner.embedders.0.transformer.encoder.block.9.layer.1.layer_norm.weight',
#  'conditioner.embedders.0.transformer.encoder.block.10.layer.0.SelfAttention.q.weight',
#  'conditioner.embedders.0.transformer.encoder.block.10.layer.0.SelfAttention.k.weight',
#  'conditioner.embedders.0.transformer.encoder.block.10.layer.0.SelfAttention.v.weight',
#  'conditioner.embedders.0.transformer.encoder.block.10.layer.0.SelfAttention.o.weight',
#  'conditioner.embedders.0.transformer.encoder.block.10.layer.0.layer_norm.weight',
#  'conditioner.embedders.0.transformer.encoder.block.10.layer.1.DenseReluDense.wi_0.weight',
#  'conditioner.embedders.0.transformer.encoder.block.10.layer.1.DenseReluDense.wi_1.weight',
#  'conditioner.embedders.0.transformer.encoder.block.10.layer.1.DenseReluDense.wo.weight',
#  'conditioner.embedders.0.transformer.encoder.block.10.layer.1.layer_norm.weight',
#  'conditioner.embedders.0.transformer.encoder.block.11.layer.0.SelfAttention.q.weight',
#  'conditioner.embedders.0.transformer.encoder.block.11.layer.0.SelfAttention.k.weight',
#  'conditioner.embedders.0.transformer.encoder.block.11.layer.0.SelfAttention.v.weight',
#  'conditioner.embedders.0.transformer.encoder.block.11.layer.0.SelfAttention.o.weight',
#  'conditioner.embedders.0.transformer.encoder.block.11.layer.0.layer_norm.weight',
#  'conditioner.embedders.0.transformer.encoder.block.11.layer.1.DenseReluDense.wi_0.weight',
#  'conditioner.embedders.0.transformer.encoder.block.11.layer.1.DenseReluDense.wi_1.weight',
#  'conditioner.embedders.0.transformer.encoder.block.11.layer.1.DenseReluDense.wo.weight',
#  'conditioner.embedders.0.transformer.encoder.block.11.layer.1.layer_norm.weight',
#  'conditioner.embedders.0.transformer.encoder.block.12.layer.0.SelfAttention.q.weight',
#  'conditioner.embedders.0.transformer.encoder.block.12.layer.0.SelfAttention.k.weight',
#  'conditioner.embedders.0.transformer.encoder.block.12.layer.0.SelfAttention.v.weight',
#  'conditioner.embedders.0.transformer.encoder.block.12.layer.0.SelfAttention.o.weight',
#  'conditioner.embedders.0.transformer.encoder.block.12.layer.0.layer_norm.weight',
#  'conditioner.embedders.0.transformer.encoder.block.12.layer.1.DenseReluDense.wi_0.weight',
#  'conditioner.embedders.0.transformer.encoder.block.12.layer.1.DenseReluDense.wi_1.weight',
#  'conditioner.embedders.0.transformer.encoder.block.12.layer.1.DenseReluDense.wo.weight',
#  'conditioner.embedders.0.transformer.encoder.block.12.layer.1.layer_norm.weight',
#  'conditioner.embedders.0.transformer.encoder.block.13.layer.0.SelfAttention.q.weight',
#  'conditioner.embedders.0.transformer.encoder.block.13.layer.0.SelfAttention.k.weight',
#  'conditioner.embedders.0.transformer.encoder.block.13.layer.0.SelfAttention.v.weight',
#  'conditioner.embedders.0.transformer.encoder.block.13.layer.0.SelfAttention.o.weight',
#  'conditioner.embedders.0.transformer.encoder.block.13.layer.0.layer_norm.weight',
#  'conditioner.embedders.0.transformer.encoder.block.13.layer.1.DenseReluDense.wi_0.weight',
#  'conditioner.embedders.0.transformer.encoder.block.13.layer.1.DenseReluDense.wi_1.weight',
#  'conditioner.embedders.0.transformer.encoder.block.13.layer.1.DenseReluDense.wo.weight',
#  'conditioner.embedders.0.transformer.encoder.block.13.layer.1.layer_norm.weight',
#  'conditioner.embedders.0.transformer.encoder.block.14.layer.0.SelfAttention.q.weight',
#  'conditioner.embedders.0.transformer.encoder.block.14.layer.0.SelfAttention.k.weight',
#  'conditioner.embedders.0.transformer.encoder.block.14.layer.0.SelfAttention.v.weight',
#  'conditioner.embedders.0.transformer.encoder.block.14.layer.0.SelfAttention.o.weight',
#  'conditioner.embedders.0.transformer.encoder.block.14.layer.0.layer_norm.weight',
#  'conditioner.embedders.0.transformer.encoder.block.14.layer.1.DenseReluDense.wi_0.weight',
#  'conditioner.embedders.0.transformer.encoder.block.14.layer.1.DenseReluDense.wi_1.weight',
#  'conditioner.embedders.0.transformer.encoder.block.14.layer.1.DenseReluDense.wo.weight',
#  'conditioner.embedders.0.transformer.encoder.block.14.layer.1.layer_norm.weight',
#  'conditioner.embedders.0.transformer.encoder.block.15.layer.0.SelfAttention.q.weight',
#  'conditioner.embedders.0.transformer.encoder.block.15.layer.0.SelfAttention.k.weight',
#  'conditioner.embedders.0.transformer.encoder.block.15.layer.0.SelfAttention.v.weight',
#  'conditioner.embedders.0.transformer.encoder.block.15.layer.0.SelfAttention.o.weight',
#  'conditioner.embedders.0.transformer.encoder.block.15.layer.0.layer_norm.weight',
#  'conditioner.embedders.0.transformer.encoder.block.15.layer.1.DenseReluDense.wi_0.weight',
#  'conditioner.embedders.0.transformer.encoder.block.15.layer.1.DenseReluDense.wi_1.weight',
#  'conditioner.embedders.0.transformer.encoder.block.15.layer.1.DenseReluDense.wo.weight',
#  'conditioner.embedders.0.transformer.encoder.block.15.layer.1.layer_norm.weight',
#  'conditioner.embedders.0.transformer.encoder.block.16.layer.0.SelfAttention.q.weight',
#  'conditioner.embedders.0.transformer.encoder.block.16.layer.0.SelfAttention.k.weight',
#  'conditioner.embedders.0.transformer.encoder.block.16.layer.0.SelfAttention.v.weight',
#  'conditioner.embedders.0.transformer.encoder.block.16.layer.0.SelfAttention.o.weight',
#  'conditioner.embedders.0.transformer.encoder.block.16.layer.0.layer_norm.weight',
#  'conditioner.embedders.0.transformer.encoder.block.16.layer.1.DenseReluDense.wi_0.weight',
#  'conditioner.embedders.0.transformer.encoder.block.16.layer.1.DenseReluDense.wi_1.weight',
#  'conditioner.embedders.0.transformer.encoder.block.16.layer.1.DenseReluDense.wo.weight',
#  'conditioner.embedders.0.transformer.encoder.block.16.layer.1.layer_norm.weight',
#  'conditioner.embedders.0.transformer.encoder.block.17.layer.0.SelfAttention.q.weight',
#  'conditioner.embedders.0.transformer.encoder.block.17.layer.0.SelfAttention.k.weight',
#  'conditioner.embedders.0.transformer.encoder.block.17.layer.0.SelfAttention.v.weight',
#  'conditioner.embedders.0.transformer.encoder.block.17.layer.0.SelfAttention.o.weight',
#  'conditioner.embedders.0.transformer.encoder.block.17.layer.0.layer_norm.weight',
#  'conditioner.embedders.0.transformer.encoder.block.17.layer.1.DenseReluDense.wi_0.weight',
#  'conditioner.embedders.0.transformer.encoder.block.17.layer.1.DenseReluDense.wi_1.weight',
#  'conditioner.embedders.0.transformer.encoder.block.17.layer.1.DenseReluDense.wo.weight',
#  'conditioner.embedders.0.transformer.encoder.block.17.layer.1.layer_norm.weight',
#  'conditioner.embedders.0.transformer.encoder.block.18.layer.0.SelfAttention.q.weight',
#  'conditioner.embedders.0.transformer.encoder.block.18.layer.0.SelfAttention.k.weight',
#  'conditioner.embedders.0.transformer.encoder.block.18.layer.0.SelfAttention.v.weight',
#  'conditioner.embedders.0.transformer.encoder.block.18.layer.0.SelfAttention.o.weight',
#  'conditioner.embedders.0.transformer.encoder.block.18.layer.0.layer_norm.weight',
#  'conditioner.embedders.0.transformer.encoder.block.18.layer.1.DenseReluDense.wi_0.weight',
#  'conditioner.embedders.0.transformer.encoder.block.18.layer.1.DenseReluDense.wi_1.weight',
#  'conditioner.embedders.0.transformer.encoder.block.18.layer.1.DenseReluDense.wo.weight',
#  'conditioner.embedders.0.transformer.encoder.block.18.layer.1.layer_norm.weight',
#  'conditioner.embedders.0.transformer.encoder.block.19.layer.0.SelfAttention.q.weight',
#  'conditioner.embedders.0.transformer.encoder.block.19.layer.0.SelfAttention.k.weight',
#  'conditioner.embedders.0.transformer.encoder.block.19.layer.0.SelfAttention.v.weight',
#  'conditioner.embedders.0.transformer.encoder.block.19.layer.0.SelfAttention.o.weight',
#  'conditioner.embedders.0.transformer.encoder.block.19.layer.0.layer_norm.weight',
#  'conditioner.embedders.0.transformer.encoder.block.19.layer.1.DenseReluDense.wi_0.weight',
#  'conditioner.embedders.0.transformer.encoder.block.19.layer.1.DenseReluDense.wi_1.weight',
#  'conditioner.embedders.0.transformer.encoder.block.19.layer.1.DenseReluDense.wo.weight',
#  'conditioner.embedders.0.transformer.encoder.block.19.layer.1.layer_norm.weight',
#  'conditioner.embedders.0.transformer.encoder.block.20.layer.0.SelfAttention.q.weight',
#  'conditioner.embedders.0.transformer.encoder.block.20.layer.0.SelfAttention.k.weight',
#  'conditioner.embedders.0.transformer.encoder.block.20.layer.0.SelfAttention.v.weight',
#  'conditioner.embedders.0.transformer.encoder.block.20.layer.0.SelfAttention.o.weight',
#  'conditioner.embedders.0.transformer.encoder.block.20.layer.0.layer_norm.weight',
#  'conditioner.embedders.0.transformer.encoder.block.20.layer.1.DenseReluDense.wi_0.weight',
#  'conditioner.embedders.0.transformer.encoder.block.20.layer.1.DenseReluDense.wi_1.weight',
#  'conditioner.embedders.0.transformer.encoder.block.20.layer.1.DenseReluDense.wo.weight',
#  'conditioner.embedders.0.transformer.encoder.block.20.layer.1.layer_norm.weight',
#  'conditioner.embedders.0.transformer.encoder.block.21.layer.0.SelfAttention.q.weight',
#  'conditioner.embedders.0.transformer.encoder.block.21.layer.0.SelfAttention.k.weight',
#  'conditioner.embedders.0.transformer.encoder.block.21.layer.0.SelfAttention.v.weight',
#  'conditioner.embedders.0.transformer.encoder.block.21.layer.0.SelfAttention.o.weight',
#  'conditioner.embedders.0.transformer.encoder.block.21.layer.0.layer_norm.weight',
#  'conditioner.embedders.0.transformer.encoder.block.21.layer.1.DenseReluDense.wi_0.weight',
#  'conditioner.embedders.0.transformer.encoder.block.21.layer.1.DenseReluDense.wi_1.weight',
#  'conditioner.embedders.0.transformer.encoder.block.21.layer.1.DenseReluDense.wo.weight',
#  'conditioner.embedders.0.transformer.encoder.block.21.layer.1.layer_norm.weight',
#  'conditioner.embedders.0.transformer.encoder.block.22.layer.0.SelfAttention.q.weight',
#  'conditioner.embedders.0.transformer.encoder.block.22.layer.0.SelfAttention.k.weight',
#  ...]

# %%
model_file = '/mnt/ceph/develop/jiawei/model_checkpoint/ckpts_2b_lora/lora-disney-09-10-16-05/1/mp_rank_00_model_states.pt'
lora_original_state_dict = get_state_dict(torch.load(model_file, map_location="cpu", mmap=True))

list(lora_original_state_dict.keys())
# Out:
# /tmp/ipykernel_3373831/1864617579.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   lora_original_state_dict = get_state_dict(torch.load(model_file, map_location="cpu", mmap=True))
# ['model.diffusion_model.transformer.layers.0.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.0.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.0.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.0.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.0.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.0.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.0.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.0.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.1.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.1.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.1.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.1.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.1.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.1.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.1.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.1.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.2.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.2.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.2.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.2.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.2.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.2.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.2.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.2.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.3.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.3.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.3.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.3.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.3.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.3.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.3.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.3.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.4.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.4.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.4.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.4.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.4.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.4.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.4.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.4.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.5.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.5.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.5.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.5.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.5.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.5.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.5.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.5.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.6.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.6.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.6.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.6.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.6.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.6.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.6.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.6.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.7.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.7.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.7.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.7.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.7.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.7.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.7.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.7.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.8.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.8.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.8.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.8.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.8.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.8.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.8.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.8.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.9.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.9.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.9.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.9.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.9.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.9.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.9.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.9.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.10.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.10.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.10.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.10.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.10.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.10.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.10.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.10.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.11.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.11.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.11.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.11.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.11.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.11.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.11.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.11.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.12.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.12.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.12.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.12.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.12.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.12.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.12.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.12.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.13.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.13.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.13.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.13.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.13.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.13.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.13.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.13.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.14.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.14.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.14.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.14.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.14.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.14.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.14.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.14.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.15.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.15.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.15.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.15.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.15.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.15.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.15.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.15.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.16.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.16.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.16.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.16.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.16.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.16.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.16.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.16.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.17.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.17.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.17.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.17.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.17.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.17.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.17.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.17.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.18.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.18.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.18.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.18.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.18.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.18.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.18.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.18.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.19.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.19.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.19.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.19.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.19.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.19.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.19.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.19.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.20.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.20.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.20.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.20.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.20.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.20.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.20.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.20.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.21.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.21.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.21.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.21.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.21.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.21.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.21.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.21.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.22.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.22.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.22.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.22.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.22.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.22.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.22.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.22.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.23.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.23.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.23.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.23.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.23.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.23.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.23.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.23.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.24.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.24.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.24.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.24.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.24.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.24.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.24.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.24.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.25.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.25.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.25.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.25.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.25.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.25.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.25.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.25.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.26.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.26.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.26.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.26.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.26.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.26.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.26.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.26.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.27.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.27.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.27.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.27.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.27.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.27.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.27.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.27.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.28.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.28.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.28.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.28.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.28.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.28.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.28.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.28.attention.dense.matrix_B.0',
#  'model.diffusion_model.transformer.layers.29.attention.query_key_value.matrix_A.0',
#  'model.diffusion_model.transformer.layers.29.attention.query_key_value.matrix_A.1',
#  'model.diffusion_model.transformer.layers.29.attention.query_key_value.matrix_A.2',
#  'model.diffusion_model.transformer.layers.29.attention.query_key_value.matrix_B.0',
#  'model.diffusion_model.transformer.layers.29.attention.query_key_value.matrix_B.1',
#  'model.diffusion_model.transformer.layers.29.attention.query_key_value.matrix_B.2',
#  'model.diffusion_model.transformer.layers.29.attention.dense.matrix_A.0',
#  'model.diffusion_model.transformer.layers.29.attention.dense.matrix_B.0',
#  'conditioner.embedders.0.transformer.encoder.embed_tokens.weight']
